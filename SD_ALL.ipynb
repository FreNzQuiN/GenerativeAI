# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install font-roboto
# !pip install realesrgan
# !pip install insightface

a="stable"
b="Stable"
c="sd"
# !pip install --upgrade fastapi==0.90.1
# !git clone https://github.com/AUTOMATIC1111/{a}-diffusion-webui
# !git clone https://github.com/Mikubill/{c}-webui-controlnet /content/{a}-diffusion-webui/extensions/{c}-webui-controlnet
# !git clone https://github.com/fkunn1326/openpose-editor /content/{a}-diffusion-webui/extensions/openpose-editor
# !git clone https://github.com/yfszzx/{a}-diffusion-webui-images-browser /content/{a}-diffusion-webui/extensions/{a}-diffusion-webui-images-browser
# !git clone https://github.com/DominikDoom/a1111-{c}-webui-tagcomplete /content/{a}-diffusion-webui/extensions/a1111-{c}-webui-tagcomplete

# Model Code
#@markdown **Choose Model**
NoobAI1_1 = False #@param {type:'boolean'}
Cetusmix2 = False #@param {type:'boolean'}
Abyssorange = True #@param {type:'boolean'}
CounterFeit25 = False #@param {type:'boolean'}
DreamlikePhotoReal20 = False #@param {type:"boolean"}
AbyssOrange3A3 = False #@param {type:'boolean'}
Anything5 = False #@param {type:'boolean'}
Anypastel = False #@param {type:'boolean'}
MeinaHent = False #@param {type:'boolean'}
Meinamix = False #@param {type:'boolean'}
Pastelmix = False #@param {type:'boolean'}

if Anything5:
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/anythingv5.safetensors https://huggingface.co/nolanaatama/nythngv5/resolve/main/nythngv5.safetensors
if CounterFeit25:
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/counterfeitv25.safetensors https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5_pruned.safetensors
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/counterfeitv25.vae.pt https://huggingface.co/gsdf/Counterfeit-V2.5/resolve/main/Counterfeit-V2.5.vae.pt
if DreamlikePhotoReal20:
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/dreamlikephotoreal2.ckpt https://huggingface.co/dreamlike-art/dreamlike-photoreal-2.0/resolve/main/dreamlike-photoreal-2.0.ckpt
if AbyssOrange3A3:
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/abyssorangemix3A3.safetensors https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix3/AOM3A3_orangemixs.safetensors
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/abyssorangemix3A3.vae.pt https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt
if MeinaHent:
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/meinahentai.safetensors https://huggingface.co/nolanaatama/mnhnt/resolve/main/mnhnt.safetensors
if Meinamix:
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/meinav8.safetensors https://huggingface.co/nolanaatama/mnmx/resolve/main/mnmx.safetensors
if Pastelmix:
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/pastelmix.ckpt https://huggingface.co/andite/pastel-mix/resolve/main/pastelmix-better-vae-fp32.ckpt
if Anypastel:
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/anypastel.safetensors https://huggingface.co/nolanaatama/nypstl/resolve/main/nypstl.safetensors
  # !curl -Lo /content/sd-webui/models/Stable-diffusion/anypastel.vae.pt https://huggingface.co/nolanaatama/nypstl/resolve/main/nypstl.vae.pt

if NoobAI1_1:
  # !curl -Lo NoobAI-XL-v1.1.safetensors https://huggingface.co/Laxhar/noobai-XL-1.1/blob/main/NoobAI-XL-v1.1.safetensors
  # !mv "/content/NoobAI-XL-v1.1.safetensors" "/content/{a}-diffusion-webui/models/{b}-diffusion"
if Cetusmix2:
  # !curl -Lo cetusMix_cetusVersion2.safetensors https://huggingface.co/digiplay/Cetus-Mix-Codaedition_diffusers/blob/main/cetusMix_cetusVersion2.safetensors
  # !mv "/content/cetusMix_cetusVersion2.safetensors" "/content/{a}-diffusion-webui/models/{b}-diffusion"
if Abyssorange:
  # !curl -Lo abyssorangemix2.safetensors https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_hard.safetensors
  # !curl -Lo abyssorangemix2.vae.pt https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt
  # !mv "/content/abyssorangemix2.safetensors" "/content/{a}-diffusion-webui/models/{b}-diffusion"
  # !mv "/content/abyssorangemix2.vae.pt" "/content/{a}-diffusion-webui/models/{b}-diffusion"

# ControlNet
CONTROLNET = True #@param {type:'boolean'}
if CONTROLNET:
  #lineart
  # !curl -Lo /content/microsoftexcel/extensions/microsoftexcel-controlnet/models/control_v11p_sd15_inpaint.safetensors https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors
  # !curl -Lo /content/microsoftexcel/extensions/microsoftexcel-controlnet/models/control_v11p_sd15_lineart.safetensors https://huggingface.co/nolanaatama/models/resolve/main/control_v11p_sd15_lineart_fp16.safetensors
  #canny
  # !curl -Lo control_canny-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors
  # !mv "/content/control_canny-fp16.safetensors" "/content/{a}-diffusion-webui/extensions/{c}-webui-controlnet/models"
  # depth
  # !curl -Lo control_depth-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors
  # !mv "/content/control_depth-fp16.safetensors" "/content/{a}-diffusion-webui/extensions/{c}-webui-controlnet/models"
  # hed
  # !curl -Lo control_hed-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors
  # !mv "/content/control_hed-fp16.safetensors" "/content/{a}-diffusion-webui/extensions/{c}-webui-controlnet/models"
  # mlsd
  # !curl -Lo control_mlsd-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors
  # !mv "/content/control_mlsd-fp16.safetensors" "/content/{a}-diffusion-webui/extensions/{c}-webui-controlnet/models"
  # normal
  # !curl -Lo control_normal-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors
  # !mv "/content/control_normal-fp16.safetensors" "/content/{a}-diffusion-webui/extensions/{c}-webui-controlnet/models"
  # openpose
  # !curl -Lo control_openpose-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors
  # !mv "/content/control_openpose-fp16.safetensors" "/content/{a}-diffusion-webui/extensions/{c}-webui-controlnet/models"
  # scribble
  # !curl -Lo control_scribble-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors
  # !mv "/content/control_scribble-fp16.safetensors" "/content/{a}-diffusion-webui/extensions/{c}-webui-controlnet/models"
  # seg
  # !curl -Lo control_seg-fp16.safetensors https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors
  # !mv "/content/control_seg-fp16.safetensors" "/content/{a}-diffusion-webui/extensions/{c}-webui-controlnet/models"
  import shutil
  shutil.rmtree(f'/content/{a}-diffusion-webui/embeddings')
  # %cd /content/{a}-diffusion-webui
  # !git checkout 3715ece
  # !git clone https://huggingface.co/nolanaatama/embeddings

# !rm "/content/stable-diffusion-webui/requirements.txt"
# !rm "/content/stable-diffusion-webui/requirements_versions.txt"
# !cp "/content/drive/MyDrive/Colab Notebooks/requirements.txt" "/content/{a}-diffusion-webui/"
# !cp "/content/drive/MyDrive/Colab Notebooks/requirements_versions.txt" "/content/{a}-diffusion-webui/"

# !rm "/usr/local/lib/python3.10/dist-packages/basicsr/data/degradations.py"
# !cp "/content/drive/MyDrive/Colab Notebooks/degradations.py" "/usr/local/lib/python3.10/dist-packages/basicsr/data/"
# !rm "/content/stable-diffusion-webui/repositories/{a}-diffusion-stability-ai/ldm/models/diffusion/ddpm.py"
# !cp "/content/drive/MyDrive/Colab Notebooks/ddpm.py" "/content/{a}-diffusion-webui/repositories/{a}-diffusion-stability-ai/ldm/models/diffusion/"
# !rm "/content/stable-diffusion-webui/modules/images.py"
# !cp "/content/drive/MyDrive/Colab Notebooks/images.py" "/content/{a}-diffusion-webui/modules/"
# !rm "/content/stable-diffusion-webui/modules/textual_inversion/image_embedding.py"
# !cp "/content/drive/MyDrive/Colab Notebooks/image_embedding.py" "/content/{a}-diffusion-webui/modules/textual_inversion/"

# !rm "/content/{a}-diffusion-webui/extensions-builtin/LDSR/{c}_hijack_ddpm_v1.py"
# !cp "/content/drive/MyDrive/Colab Notebooks/{c}_hijack_ddpm_v1.py" "/content/{a}-diffusion-webui/extensions-builtin/LDSR/"


RUN = True #@param {type:'boolean'}
if RUN:
  # !COMMANDLINE_ARGS="--share --opt-split-attention --disable-safe-unpickle --no-half-vae --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 34787, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 34787 (delta 9), reused 9 (delta 6), pack-reused 34771 (from 1)
# Receiving objects: 100% (34787/34787), 35.40 MiB | 33.44 MiB/s, done.
# Resolving deltas: 100% (24292/24292), done.
# fatal: destination path '/content/stable-diffusion-webui/extensions/sd-webui-controlnet' already exists and is not an empty directory.
# fatal: destination path '/content/stable-diffusion-webui/extensions/openpose-editor' already exists and is not an empty directory.
# fatal: destination path '/content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser' already exists and is not an empty directory.
# ...

# %%
# ABYSSORANGEMIX2
#!curl -Lo abyssorangemix2.safetensors https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/Models/AbyssOrangeMix2/AbyssOrangeMix2_hard.safetensors
#!curl -Lo abyssorangemix2.vae.pt https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt
#!mv "/content/abyssorangemix2.safetensors" "/content/{a}-diffusion-webui/models/{b}-diffusion"
#!mv "/content/abyssorangemix2.vae.pt" "/content/{a}-diffusion-webui/models/{b}-diffusion"
#from torchvision.transforms.functional import rgb_to_grayscale

# !COMMANDLINE_ARGS="--share --disable-safe-unpickle --no-half-vae --opt-split-attention --enable-insecure-extension-access" REQS_FILE="requirements.txt" python launch.py
# Out:
# Python 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# Commit hash: 3715ece0adce7bf7c5e9c5ab3710b2fdc3848f39
# Installing requirements for Web UI
#
# Launching Web UI with arguments: --share --disable-safe-unpickle --no-half-vae --opt-split-attention --enable-insecure-extension-access
# No module 'xformers'. Proceeding without it.
# 2024-12-05 06:19:57.130097: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-05 06:19:57.163488: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-05 06:19:57.174158: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !rm "/content/stable-diffusion-webui/requirements.txt"
# !rm "/content/stable-diffusion-webui/requirements_versions.txt"
# !cp "/content/drive/MyDrive/Colab Notebooks/requirements.txt" "/content/stable-diffusion-webui/"
# !cp "/content/drive/MyDrive/Colab Notebooks/requirements_versions.txt" "/content/stable-diffusion-webui/"
# !rm "/usr/local/lib/python3.10/dist-packages/basicsr/data/degradations.py"
# !cp "/content/drive/MyDrive/Colab Notebooks/degradations.py" "/usr/local/lib/python3.10/dist-packages/basicsr/data/"
# !rm "/content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/models/diffusion/ddpm.py"
# !cp "/content/drive/MyDrive/Colab Notebooks/ddpm.py" "/content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/ldm/models/diffusion/"
# !rm "/content/stable-diffusion-webui/modules/images.py"
# !cp "/content/drive/MyDrive/Colab Notebooks/images.py" "/content/stable-diffusion-webui/modules/"
# !rm "/content/stable-diffusion-webui/modules/textual_inversion/image_embedding.py"
# !cp "/content/drive/MyDrive/Colab Notebooks/image_embedding.py" "/content/stable-diffusion-webui/modules/textual_inversion/"
# !rm "/content/{a}-diffusion-webui/extensions-builtin/LDSR/{c}_hijack_ddpm_v1.py"
# !cp "/content/drive/MyDrive/Colab Notebooks/{c}_hijack_ddpm_v1.py" "/content/{a}-diffusion-webui/extensions-builtin/LDSR/"

# %%
#@title (STEP 1) Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#@title Manual Save FIles in drives
TheDate = "2024-12-04" #@param {type:'string'}
# !mv "/content/stable-diffusion-webui/outputs//txt2img-images/"* "/content/drive/MyDrive//Colab Notebooks/"
